# %% [markdown]
# <a href="https://colab.research.google.com/github/yashdeeptehlan/hello-world/blob/main/Python_Day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("I am Yashdeep and i am going to get this job.")
# Out:
# I am Yashdeep and i am going to get this job.

# %%
name = "Yashdeep"
age = 26
monthly_expense = 3000

print(name)
print(age)
print(monthly_expense)
# Out:
# Yashdeep
# 26
# 3000

# %%
hourly_rate = 18
hours_per_week = 40
weeks_per_month = 4

monthly_income = hourly_rate * hours_per_week * weeks_per_month
gap = monthly_expense - monthly_income

print("Monthy income:", monthly_income)
print("Gap:", gap)
# Out:
# Monthy income: 2880
# Gap: 120

# %%
print("My name is "+ name +" and I am "+ str(age) +" years old.")
# Out:
# My name is Yashdeep and I am 26 years old.

# %%
print(f"My name is {name} and i am {age} years old.")
# Out:
# My name is Yashdeep and i am 26 years old.

# %%
skills = ["Python", "RAG", "FastAPI", "SQL"]
skills.append("Docker")

print(f"I have {len(skills)} skills.")
print(f"My newest skill is {skills[-1]}")
# Out:
# I have 5 skills.
# My newest skill is Docker

# %%
skills = ["Python", "RAG", "FastAPI", "SQL", "Docker"]

for skill in skills:
  print(f"I have {skill}")
# Out:
# I have Python
# I have RAG
# I have FastAPI
# I have SQL
# I have Docker

# %%
name = "Yashdeep"
skills = ["Python", "RAG", "FastAPI", "SQL", "Docker"]
monthly_expenses = 3000
jobs_applied = 0
target_salary = 70000

print(f"Name: {name}")
print(f"Jobs applied: {jobs_applied}")
print(f"Monthly expenses: {monthly_expenses}")
print(f"Targer salary: {target_salary}")
print(f"Skills i am building:")

for skill in skills:
  print(f" - {skill}")
# Out:
# Name: Yashdeep
# Jobs applied: 0
# Monthly expenses: 3000
# Targer salary: 70000
# Skills i am building:
#  - Python
#  - RAG
#  - FastAPI
#  - SQL
#  - Docker

# %%
companies = ["Google", "Meta", "Netflix"]
companies.append("Tesla")

print(f"Applying to total {len(companies)} companies.")
for company in companies:
  print(f"Applying to: {company}")
# Out:
# Applying to total 4 companies.
# Applying to: Google
# Applying to: Meta
# Applying to: Netflix
# Applying to: Tesla
